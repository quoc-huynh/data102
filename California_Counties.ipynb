# %%
import pandas as pd

# %%
df = pd.read_csv('Global_Mobility_Report.csv')
# Out:
# /var/folders/__/8q6wtgc10gsdhs_z1lv_0r700000gn/T/ipykernel_3180/3541448081.py:1: DtypeWarning: Columns (3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Global_Mobility_Report.csv')

# %%
united_states = df[df['country_region'] == 'United States']
united_states.head()
# Out:
#         country_region_code country_region sub_region_1 sub_region_2  \
# 9104472                  US  United States          NaN          NaN
# 9104473                  US  United States          NaN          NaN
# 9104474                  US  United States          NaN          NaN
# 9104475                  US  United States          NaN          NaN
# 9104476                  US  United States          NaN          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 9104472        NaN             NaN               NaN
# 9104473        NaN             NaN               NaN
# 9104474        NaN             NaN               NaN
# 9104475        NaN             NaN               NaN
# 9104476        NaN             NaN               NaN
#
#                             place_id        date  \
# 9104472  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-15
# 9104473  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-16
# 9104474  ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2020-02-17
# ...

# %%
california_counties = united_states[united_states['sub_region_1'] == 'California']

# %%
california_counties.head()
# Out:
#         country_region_code country_region sub_region_1 sub_region_2  \
# 9253444                  US  United States   California          NaN
# 9253445                  US  United States   California          NaN
# 9253446                  US  United States   California          NaN
# 9253447                  US  United States   California          NaN
# 9253448                  US  United States   California          NaN
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 9253444        NaN           US-CA               NaN
# 9253445        NaN           US-CA               NaN
# 9253446        NaN           US-CA               NaN
# 9253447        NaN           US-CA               NaN
# 9253448        NaN           US-CA               NaN
#
#                             place_id        date  \
# 9253444  ChIJPV4oX_65j4ARVW8IJ6IJUYs  2020-02-15
# 9253445  ChIJPV4oX_65j4ARVW8IJ6IJUYs  2020-02-16
# 9253446  ChIJPV4oX_65j4ARVW8IJ6IJUYs  2020-02-17
# ...

# %%
california_counties.to_csv('California_Counties.csv')
